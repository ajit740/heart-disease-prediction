# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# we have to read the file 
df=pd.read_csv(r'C:\Users\Ajit\Downloads/heart.csv')

# %%
# this is use to see the dataset(df-->dataFrame)
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
# to see first five dataset
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
# to see the last five dataset
df.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %%
# to see the random data 
df.sample()
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 43   53    0   0     130   264    0        0       143     0      0.4    1
#
#     caa  thall  output
# 43    0      2       1

# %%
# to see the information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# to see the correlation of data
df.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thall     0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %% [markdown]
# # handling missing values

# %%
# to handle missing value
df.isnull()
# Out:
#        age    sex     cp  trtbps   chol    fbs  restecg  thalachh   exng  \
# 0    False  False  False   False  False  False    False     False  False
# 1    False  False  False   False  False  False    False     False  False
# 2    False  False  False   False  False  False    False     False  False
# 3    False  False  False   False  False  False    False     False  False
# 4    False  False  False   False  False  False    False     False  False
# ..     ...    ...    ...     ...    ...    ...      ...       ...    ...
# 298  False  False  False   False  False  False    False     False  False
# 299  False  False  False   False  False  False    False     False  False
# 300  False  False  False   False  False  False    False     False  False
# 301  False  False  False   False  False  False    False     False  False
# 302  False  False  False   False  False  False    False     False  False
#
#      oldpeak    slp    caa  thall  output
# 0      False  False  False  False   False
# ...

# %%
# this is used to see the total null value present in the data
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %% [markdown]
# # performing analysis on data

# %%
# to see unique sex in the dataset
df['sex'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# to see male sex trtbps
df.loc[df['sex']==1,['sex','trtbps']]
# Out:
#      sex  trtbps
# 0      1     145
# 1      1     130
# 3      1     120
# 5      1     140
# 7      1     120
# ..   ...     ...
# 295    1     140
# 297    1     164
# 299    1     110
# 300    1     144
# 301    1     130
#
# [207 rows x 2 columns]

# %%
# to see female sex trtbps
df.loc[df['sex']==0,['sex','trtbps']]
# Out:
#      sex  trtbps
# 2      0     130
# 4      0     120
# 6      0     140
# 11     0     130
# 14     0     150
# ..   ...     ...
# 289    0     128
# 292    0     170
# 296    0     124
# 298    0     140
# 302    0     130
#
# [96 rows x 2 columns]

# %%
# to check the people who have high_blood_pressure 
high_blood_pressure=df.loc[df['trtbps']>120,['sex','trtbps']]
high_blood_pressure
# there are 206 people who has high blood pressure.
# Out:
#      sex  trtbps
# 0      1     145
# 1      1     130
# 2      0     130
# 5      1     140
# 6      0     140
# ..   ...     ...
# 297    1     164
# 298    0     140
# 300    1     144
# 301    1     130
# 302    0     130
#
# [206 rows x 2 columns]

# %%
# lets check males data who have high_blood_pressure
high_blood_pressure.loc[high_blood_pressure['sex']==1,['sex','trtbps']]

# there are 139 male people who has high blood pressur
# Out:
#      sex  trtbps
# 0      1     145
# 1      1     130
# 5      1     140
# 8      1     172
# 9      1     150
# ..   ...     ...
# 293    1     152
# 295    1     140
# 297    1     164
# 300    1     144
# 301    1     130
#
# [139 rows x 2 columns]

# %%
# lets check females data who have high_blood_pressure
high_blood_pressure.loc[high_blood_pressure['sex']==0,['sex','trtbps']]

# there are 67 female people who has high blood pressur
# Out:
#      sex  trtbps
# 2      0     130
# 6      0     140
# 11     0     130
# 14     0     150
# 17     0     150
# ..   ...     ...
# 289    0     128
# 292    0     170
# 296    0     124
# 298    0     140
# 302    0     130
#
# [67 rows x 2 columns]

# %%
# lets count the person who have not high_blood_pressure
normal_blood_prssure=df.loc[df['trtbps']<120,['sex','trtbps']]
normal_blood_prssure.count()

# there are 60 people who has not high blood pressure
# Out:
# sex       60
# trtbps    60
# dtype: int64

# %%
# to check unique type of chestpain
df['cp'].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
df.loc[df['cp']==2,['age','cp']]
#in this data there are 87 people which is having 2nd type of chest pain
# Out:
#      age  cp
# 1     37   2
# 8     52   2
# 9     57   2
# 11    48   2
# 15    50   2
# ..   ...  ..
# 240   70   2
# 249   69   2
# 267   49   2
# 282   59   2
# 293   67   2
#
# [87 rows x 2 columns]

# %%
# to see the unique type of blood_sugar

df['fbs'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.loc[df['fbs']==0,['fbs','trtbps']]

# there are 258 person who has not blood sugar
# Out:
#      fbs  trtbps
# 1      0     130
# 2      0     130
# 3      0     120
# 4      0     120
# 5      0     140
# ..   ...     ...
# 296    0     124
# 298    0     140
# 299    0     110
# 301    0     130
# 302    0     130
#
# [258 rows x 2 columns]

# %%
df.loc[df['fbs']==1,['fbs','trtbps']].count()

# there are 45 person who has blood sugar
# Out:
# fbs       45
# trtbps    45
# dtype: int64

# %%
df['thalachh'].aggregate([min,max])

# in this dataset the minimum 'heart rate acchived' 71 and the maximum 'heart rate achhived' 202
# Out:
# min     71
# max    202
# Name: thalachh, dtype: int64

# %% [markdown]
# # performing visualisation in the dataset

# %%
# to see heatmap of data
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# to see the distplot of data
sns.distplot(df.corr())
# Out:
# C:\Users\Ajit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# to see the countplot of sex gender
sns.countplot('sex',data=df)
# Out:
# C:\Users\Ajit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# to see countplot of chestpain
sns.countplot('cp',data=df)
# Out:
# C:\Users\Ajit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
# to check maximum and minimum value of cholestrol
min_and_max_of_chol=df['chol'].aggregate([min,max])
min_and_max_of_chol
# Out:
# min    126
# max    564
# Name: chol, dtype: int64

# %%
sns.distplot(df['thalachh'])
# Out:
# C:\Users\Ajit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='thalachh', ylabel='Density'>

# %%
sns.distplot(df.age)
# Out:
# C:\Users\Ajit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.boxplot(x = 'sex', y = 'age',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
max_chol_male=df[df['sex']==1]['chol'].max()
min_chol_male=df[df['sex']==1]['chol'].min()
max_chol_female=df[df['sex']==0]['chol'].max()
min_chol_female=df[df['sex']==0]['chol'].min()
data=[max_chol_male,min_chol_male,max_chol_female,min_chol_female]
mylabels=['max_chol_male','min_chol_male','max_chol_female','min_chol_female']
plt.pie(data,labels=mylabels,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x16d33479070>,
# ...
#  [Text(0.6517475467157966, 0.8861292994534944, 'max_chol_male'),
#   Text(-0.6540965308604697, 0.884396816093488, 'min_chol_male'),
#   Text(-0.6864905239395561, -0.8594944796455612, 'max_chol_female'),
#   Text(1.023910357062095, -0.40200445358350617, 'min_chol_female')],
#  [Text(0.35549866184497997, 0.48334325424736047, '29.81'),
#   Text(-0.35677992592389257, 0.4823982633237206, '10.64'),
#   Text(-0.37444937669430334, -0.4688151707157606, '47.64'),
#   Text(0.5584965583975063, -0.21927515650009424, '11.91')])

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
# lets split the data into X and Y
X=df[['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
       'exng', 'oldpeak', 'slp', 'caa', 'thall',]]

# %%
y=df[['output']]

# %%
# now we have to import train test split
from sklearn.model_selection import train_test_split

# %%
# now split the value in X_tes, X_train,y_test,y_train
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=100)

# %%
X_train
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 162   41    1   1     120   157    0        1       182     0      0.0    2
# 112   64    0   2     140   313    0        1       133     0      0.2    2
# 278   58    0   1     136   319    1        0       152     0      0.0    2
# 209   59    1   0     140   177    0        1       162     1      0.0    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 66    51    1   2     100   222    0        1       143     1      1.2    1
# 53    44    0   2     108   141    0        1       175     0      0.6    1
# 79    58    1   2     105   240    0        0       154     1      0.6    1
# 280   42    1   0     136   315    0        1       125     1      1.8    1
# 8     52    1   2     172   199    1        1       162     0      0.5    2
#
#      caa  thall
# 3      0      2
# 162    0      2
# ...

# %%
X_test
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 69    62    0   0     124   209    0        1       163     0      0.0    2
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 220   63    0   0     150   407    0        0       154     0      4.0    1
# 134   41    0   1     126   306    0        1       163     0      0.0    2
# 7     44    1   1     120   263    0        1       173     0      0.0    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 203   68    1   2     180   274    1        0       150     1      1.6    1
# 237   60    1   0     140   293    0        0       170     0      1.2    1
# 29    53    1   2     130   197    1        0       152     0      1.2    0
# 161   55    0   1     132   342    0        1       166     0      1.2    2
# 266   55    0   0     180   327    0        2       117     1      3.4    1
#
#      caa  thall
# 69     0      2
# 300    2      3
# ...

# %%
y_test
# Out:
#      output
# 69        1
# 300       0
# 220       0
# 134       1
# 7         1
# ..      ...
# 203       0
# 237       0
# 29        1
# 161       1
# 266       0
#
# [91 rows x 1 columns]

# %%
y_train
# Out:
#      output
# 3         1
# 162       1
# 112       1
# 278       0
# 209       0
# ..      ...
# 66        1
# 53        1
# 79        1
# 280       0
# 8         1
#
# [212 rows x 1 columns]

# %% [markdown]
# # LinearRegression

# %%
# now we have to import Linear regression
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
# now we have to fit the x_train and Y_train
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# to see the intercept rate of data
lr.intercept_
# Out:
# array([0.80389916])

# %%
# to see the cofficent  rate of data
lr.coef_
# Out:
# array([[ 0.00134561, -0.1973454 ,  0.09901956, -0.00107892, -0.00065413,
#         -0.05237971,  0.03686138,  0.00296245, -0.06454269, -0.06136514,
#          0.09051021, -0.11560018, -0.17068416]])

# %%
# to see the predicton rate
pred=lr.predict(X_test)

# %%
# prediction percentage
pred
# Out:
# array([[ 0.97622106],
#        [-0.04275288],
#        [-0.09698094],
#        [ 0.98137486],
#        [ 0.68160752],
#        [ 0.05456446],
#        [ 0.14358323],
#        [ 0.35449318],
#        [ 0.63205226],
#        [ 0.59254462],
#        [ 0.34013569],
#        [ 0.56581096],
#        [ 0.3616793 ],
#        [ 0.5726999 ],
#        [ 0.16136173],
#        [ 0.56756762],
#        [ 0.29784262],
#        [ 0.34100467],
#        [ 0.16171027],
#        [ 0.46277828],
#        [ 0.48026612],
#        [ 0.9718229 ],
#        [ 0.38374802],
#        [ 0.96887478],
#        [ 1.09077795],
#        [ 0.13516021],
#        [-0.17896301],
#        [ 0.84414122],
#        [-0.06549625],
#        [-0.17460196],
#        [ 0.99791375],
#        [ 1.22961924],
#        [-0.03773933],
#        [ 0.63749321],
#        [ 0.15627178],
#        [ 0.95238062],
#        [ 0.41378864],
#        [ 0.93192406],
#        [ 1.08633837],
#        [ 0.79608152],
#        [ 0.5533568 ],
# ...

# %%
plt.plot(pred,X_test)

# %%
# to see scatter_plot
plt.scatter(pred,y_test)

# %% [markdown]
# # conclusion:-

# %%
# In the data set we analyse the data ,filter the data and visualize throgh some graphs 
# then we use machine learning model for prediction 
# there are 206 people who has high blood pressure.
# there are 139 male people who has high blood pressure.
# there are 67 female people who has high blood pressure.
# there are 60 people who has not high blood pressure
# there are 87 people which is having 2nd type of chest pain
# there are 258 person who has not blood sugar
# there are 45 person who has blood sugar
# in this dataset the minimum 'heart rate acchived' 71 and the maximum 'heart rate achhived' 202
# maximum value of cholestrol 564
# minimum value of cholestrol 126
# intercept percentage of the data=80%
